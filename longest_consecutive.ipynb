# %% [markdown]
# <a href="https://colab.research.google.com/github/vishakhasoni284-hub/python_dsa_practice/blob/main/longest_consecutive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Longest consecutive sequence
"""Given an unsorted array of integers nums, return the length of the longest
consecutive elements sequence.

You must write an algorithm that runs in O(n) time.

Constraints:

0 <= nums.length <= 105
-109 <= nums[i] <= 109
"""

class Solution(object):
    def longestConsecutive(self, nums):
        hash_dict={}
        max_length=0
        for num in nums:
            hash_dict[num]=1
        num=0
        for index in hash_dict:
            curr_length=0
            if index-1 in hash_dict:
                pass
            else:
                while(index in hash_dict):
                    curr_length+=1
                    index=index+1
            if curr_length>max_length:
                max_length=curr_length
        return max_length
